# %% [markdown]
# # Test datasets
# This notebook has been constructed to assist the inclusion of an example in the documentation of the package - that can be carried out by anyone attempting to use the function.

# %%
import pandas as pd
import geopandas as gpd
import libpysal

# %% [markdown]
# ## PySAL datasets
#
# using code `pysal.open(pysal.examples.get_path("DATASET.EXTENSION")).read()`
#
# pysal.open(pysal.examples.get_path("10740.shp")).read()

# %%
from libpysal.examples import available
available()
# Out:
# ...
# Example not downloaded: Chicago parcels
# ...
# Example not downloaded: Chile Migration
# ...
# Example not downloaded: Spirals
# ...
#          Name                                        Description  Installed
# 0       10740  Albuquerque, New Mexico, Census 2000 Tract Dat...       True
# 1      AirBnB  Airbnb rentals, socioeconomics, and crime in C...       True
# 2     Atlanta       Atlanta, GA region homicide counts and rates       True
# 3   Baltimore          Baltimore house sales prices and hedonics       True
# 4   Bostonhsg               Boston housing and neighborhood data       True
# ..        ...                                                ...        ...
# 93        taz           Traffic Analysis Zones in So. California       True
# 94      tokyo                               Tokyo Mortality data       True
# 95  us_income  Per-capita income for the lower 48 US states 1...       True
# 96   virginia                        Virginia counties shapefile       True
# ...

# %%
cincin = load_example('Cincinnati')
cincin.get_file_list()
# Out:
# ['/Users/noahbouchier/pysal_data/Cincinnati/walnuthills_updated/.DS_Store',
#  '/Users/noahbouchier/pysal_data/Cincinnati/walnuthills_updated/cincinnati.prj',
#  '/Users/noahbouchier/pysal_data/Cincinnati/walnuthills_updated/cincinnati.shx',
#  '/Users/noahbouchier/pysal_data/Cincinnati/walnuthills_updated/cincinnati.shp',
#  '/Users/noahbouchier/pysal_data/Cincinnati/walnuthills_updated/cincinnati.dbf',
#  '/Users/noahbouchier/pysal_data/Cincinnati/__MACOSX/walnuthills_updated/._.DS_Store']

# %%
cincin_df = gpd.read_file(cincin.get_path('cincinnati.shp'))
cincin_df.plot()
# Out:
# <AxesSubplot:>

# %%
cincin_df.head()
# Out:
#          ID  AREA            BLOCK            BG        TRACT COUNTY   MSA  \
# 0  726907.0  0.09  390610042002001  390610042002  39061004200  39061  1640
# 1  695744.0  0.01  390610022004003  390610022004  39061002200  39061  1640
# 2  695762.0  0.01  390610033002017  390610033002  39061003300  39061  1640
# 3  695780.0  0.01  390610022004002  390610022004  39061002200  39061  1640
# 4  695798.0  0.02  390610033001009  390610033001  39061003300  39061  1640
#
#    POPULATION   MALE  FEMALE  ...  OWNER_SIZE  RENTER_SIZ     DENSITY  \
# 0       479.0  221.0   258.0  ...        1.46        1.42   5384.7901
# 1        85.0   39.0    46.0  ...        3.22        2.15   6643.1423
# 2        29.0   18.0    11.0  ...        1.00        1.33   4326.5018
# 3       117.0   59.0    58.0  ...        2.57        2.25  20784.6991
# 4        96.0   51.0    45.0  ...        1.00        1.42   4019.0506
#
#    BURGLARY  ASSAULT  THEFT  BURG_D  ASSALT_D  THEFT_D  \
# ...

# %%
print(cincin_df.columns)
# Out:
# Index(['ID', 'AREA', 'BLOCK', 'BG', 'TRACT', 'COUNTY', 'MSA', 'POPULATION',
#        'MALE', 'FEMALE', 'AGE_0_5', 'AGE_5_9', 'AGE_10_14', 'AGE_15_19',
#        'AGE_20_24', 'AGE_25_34', 'AGE_35_44', 'AGE_45_54', 'AGE_55_59',
#        'AGE_60_64', 'AGE_65_74', 'AGE_75_84', 'AGE_85', 'MEDIAN_AGE', 'AGE_18',
#        'MALE_18', 'FEMALE_18', 'AGE_21', 'AGE_62', 'AGE_65', 'MALE_65',
#        'FEMALE_65', 'F1_RACE', 'WHITE', 'BLACK', 'AMINDIAN', 'ASIAN',
#        'HAWAIIAN', 'OTHER_RACE', 'F2_RACES', 'AP_WHITE', 'AP_BLACK',
#        'AP_AMINDIA', 'AP_ASIAN', 'AP_HAWAIIA', 'AP_OTHER', 'AP_HISPANI',
#        'NOT_HISPAN', 'NH_WHITE', 'IN_HOUSEHO', 'GROUP_QUAR', 'GQ_INSTITU',
#        'GQ_NONINST', 'HOUSEHOLDS', 'HH_FAMILY', 'HH_NONFAMI', 'AVG_HHSIZE',
#        'AVG_FAMSIZ', 'HSNG_UNITS', 'HU_OCCUPIE', 'HU_VACANT', 'OCCHU_OWNE',
#        'OCCHU_RENT', 'OWNER_SIZE', 'RENTER_SIZ', 'DENSITY', 'BURGLARY',
#        'ASSAULT', 'THEFT', 'BURG_D', 'ASSALT_D', 'THEFT_D', 'geometry'],
# ...

# %%
cincin_ethnicity = cincin["ID", "F1_RACE"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-e28ae26453f0> in <module>
# ----> 1 cincin_ethnicity = cincin["ID", "F1_RACE"]
#
# TypeError: 'Example' object is not subscriptable
